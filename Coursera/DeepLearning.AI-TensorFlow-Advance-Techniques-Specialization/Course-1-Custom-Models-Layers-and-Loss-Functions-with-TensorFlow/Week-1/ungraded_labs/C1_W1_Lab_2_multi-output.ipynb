# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.legend(loc='upper right')
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
plot_model(model)

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 237.9589 - y1_output_loss: 113.8071 - y2_output_loss: 123.2362 - y1_output_root_mean_squared_error: 10.6948 - y2_output_root_mean_squared_error: 11.1167 - val_loss: 72.4844 - val_y1_output_loss: 19.1346 - val_y2_output_loss: 53.2166 - val_y1_output_root_mean_squared_error: 4.4159 - val_y2_output_root_mean_squared_error: 7.2790
# Epoch 2/500
# 614/614 [==============================] - 0s 156us/sample - loss: 33.3467 - y1_output_loss: 12.3027 - y2_output_loss: 20.7729 - y1_output_root_mean_squared_error: 3.5229 - y2_output_root_mean_squared_error: 4.5756 - val_loss: 29.4780 - val_y1_output_loss: 13.8338 - val_y2_output_loss: 15.2290 - val_y1_output_root_mean_squared_error: 3.7623 - val_y2_output_root_mean_squared_error: 3.9144
# Epoch 3/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.2455 - y1_output_loss: 9.6908 - y2_output_loss: 13.4436 - y1_output_root_mean_squared_error: 3.1152 - y2_output_root_mean_squared_error: 3.6798 - val_loss: 22.4302 - val_y1_output_loss: 10.8707 - val_y2_output_loss: 11.2144 - val_y1_output_root_mean_squared_error: 3.3442 - val_y2_output_root_mean_squared_error: 3.3536
# Epoch 4/500
# 614/614 [==============================] - 0s 168us/sample - loss: 22.4612 - y1_output_loss: 8.7986 - y2_output_loss: 13.6400 - y1_output_root_mean_squared_error: 2.9659 - y2_output_root_mean_squared_error: 3.6966 - val_loss: 33.0496 - val_y1_output_loss: 12.6995 - val_y2_output_loss: 19.9259 - val_y1_output_root_mean_squared_error: 3.6047 - val_y2_output_root_mean_squared_error: 4.4784
# Epoch 5/500
# 614/614 [==============================] - 0s 149us/sample - loss: 24.0366 - y1_output_loss: 8.8292 - y2_output_loss: 15.1363 - y1_output_root_mean_squared_error: 2.9712 - y2_output_root_mean_squared_error: 3.8998 - val_loss: 20.4295 - val_y1_output_loss: 9.4240 - val_y2_output_loss: 10.8349 - val_y1_output_root_mean_squared_error: 3.1073 - val_y2_output_root_mean_squared_error: 3.2824
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.7955 - y1_output_loss: 9.0132 - y2_output_loss: 14.6268 - y1_output_root_mean_squared_error: 3.0130 - y2_output_root_mean_squared_error: 3.8363 - val_loss: 22.2761 - val_y1_output_loss: 9.9332 - val_y2_output_loss: 11.9073 - val_y1_output_root_mean_squared_error: 3.1948 - val_y2_output_root_mean_squared_error: 3.4741
# Epoch 7/500
# 614/614 [==============================] - 0s 135us/sample - loss: 21.8564 - y1_output_loss: 8.4309 - y2_output_loss: 13.2983 - y1_output_root_mean_squared_error: 2.9139 - y2_output_root_mean_squared_error: 3.6559 - val_loss: 27.0669 - val_y1_output_loss: 11.1482 - val_y2_output_loss: 15.6600 - val_y1_output_root_mean_squared_error: 3.3697 - val_y2_output_root_mean_squared_error: 3.9639
# Epoch 8/500
# 614/614 [==============================] - 0s 159us/sample - loss: 22.7400 - y1_output_loss: 8.7153 - y2_output_loss: 14.1183 - y1_output_root_mean_squared_error: 2.9430 - y2_output_root_mean_squared_error: 3.7522 - val_loss: 19.2211 - val_y1_output_loss: 9.1414 - val_y2_output_loss: 9.7902 - val_y1_output_root_mean_squared_error: 3.0609 - val_y2_output_root_mean_squared_error: 3.1388
# Epoch 9/500
# 614/614 [==============================] - 0s 144us/sample - loss: 19.7565 - y1_output_loss: 7.7740 - y2_output_loss: 11.9342 - y1_output_root_mean_squared_error: 2.7948 - y2_output_root_mean_squared_error: 3.4562 - val_loss: 17.9955 - val_y1_output_loss: 8.1114 - val_y2_output_loss: 9.4934 - val_y1_output_root_mean_squared_error: 2.8896 - val_y2_output_root_mean_squared_error: 3.1057
# Epoch 10/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.2007 - y1_output_loss: 8.0580 - y2_output_loss: 13.2696 - y1_output_root_mean_squared_error: 2.8151 - y2_output_root_mean_squared_error: 3.6436 - val_loss: 26.6211 - val_y1_output_loss: 9.2261 - val_y2_output_loss: 17.0654 - val_y1_output_root_mean_squared_error: 3.0683 - val_y2_output_root_mean_squared_error: 4.1481
# Epoch 11/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.2756 - y1_output_loss: 7.5330 - y2_output_loss: 12.6002 - y1_output_root_mean_squared_error: 2.7540 - y2_output_root_mean_squared_error: 3.5625 - val_loss: 16.7095 - val_y1_output_loss: 7.8335 - val_y2_output_loss: 8.6447 - val_y1_output_root_mean_squared_error: 2.8281 - val_y2_output_root_mean_squared_error: 2.9515
# Epoch 12/500
# 614/614 [==============================] - 0s 144us/sample - loss: 24.1900 - y1_output_loss: 7.8870 - y2_output_loss: 16.1414 - y1_output_root_mean_squared_error: 2.8190 - y2_output_root_mean_squared_error: 4.0303 - val_loss: 33.2839 - val_y1_output_loss: 11.2069 - val_y2_output_loss: 22.1718 - val_y1_output_root_mean_squared_error: 3.3471 - val_y2_output_root_mean_squared_error: 4.6990
# Epoch 13/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.7194 - y1_output_loss: 6.5612 - y2_output_loss: 10.1071 - y1_output_root_mean_squared_error: 2.5603 - y2_output_root_mean_squared_error: 3.1882 - val_loss: 16.9075 - val_y1_output_loss: 7.3092 - val_y2_output_loss: 9.3524 - val_y1_output_root_mean_squared_error: 2.7383 - val_y2_output_root_mean_squared_error: 3.0675
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 16.9229 - y1_output_loss: 6.3942 - y2_output_loss: 10.7618 - y1_output_root_mean_squared_error: 2.5270 - y2_output_root_mean_squared_error: 3.2461 - val_loss: 41.1752 - val_y1_output_loss: 13.4848 - val_y2_output_loss: 27.9501 - val_y1_output_root_mean_squared_error: 3.6554 - val_y2_output_root_mean_squared_error: 5.2738
# Epoch 15/500
# 614/614 [==============================] - 0s 173us/sample - loss: 18.4637 - y1_output_loss: 6.7858 - y2_output_loss: 11.7188 - y1_output_root_mean_squared_error: 2.5924 - y2_output_root_mean_squared_error: 3.4268 - val_loss: 23.5238 - val_y1_output_loss: 8.2960 - val_y2_output_loss: 15.1684 - val_y1_output_root_mean_squared_error: 2.8924 - val_y2_output_root_mean_squared_error: 3.8933
# Epoch 16/500
# 614/614 [==============================] - 0s 152us/sample - loss: 15.7870 - y1_output_loss: 5.8612 - y2_output_loss: 9.8696 - y1_output_root_mean_squared_error: 2.4228 - y2_output_root_mean_squared_error: 3.1491 - val_loss: 14.3569 - val_y1_output_loss: 6.3644 - val_y2_output_loss: 7.7972 - val_y1_output_root_mean_squared_error: 2.5494 - val_y2_output_root_mean_squared_error: 2.8032
# Epoch 17/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.9886 - y1_output_loss: 6.1362 - y2_output_loss: 10.7327 - y1_output_root_mean_squared_error: 2.4872 - y2_output_root_mean_squared_error: 3.2867 - val_loss: 13.1957 - val_y1_output_loss: 5.7564 - val_y2_output_loss: 7.2787 - val_y1_output_root_mean_squared_error: 2.4208 - val_y2_output_root_mean_squared_error: 2.7084
# Epoch 18/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.7243 - y1_output_loss: 5.8625 - y2_output_loss: 9.1143 - y1_output_root_mean_squared_error: 2.4081 - y2_output_root_mean_squared_error: 2.9876 - val_loss: 22.4143 - val_y1_output_loss: 8.2916 - val_y2_output_loss: 14.3378 - val_y1_output_root_mean_squared_error: 2.8632 - val_y2_output_root_mean_squared_error: 3.7705
# Epoch 19/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.0663 - y1_output_loss: 5.4251 - y2_output_loss: 8.6037 - y1_output_root_mean_squared_error: 2.3332 - y2_output_root_mean_squared_error: 2.9364 - val_loss: 16.0869 - val_y1_output_loss: 7.2081 - val_y2_output_loss: 8.8046 - val_y1_output_root_mean_squared_error: 2.6939 - val_y2_output_root_mean_squared_error: 2.9715
# Epoch 20/500
# 614/614 [==============================] - 0s 158us/sample - loss: 15.4102 - y1_output_loss: 5.8174 - y2_output_loss: 9.5782 - y1_output_root_mean_squared_error: 2.4163 - y2_output_root_mean_squared_error: 3.0938 - val_loss: 18.7958 - val_y1_output_loss: 7.5130 - val_y2_output_loss: 11.3057 - val_y1_output_root_mean_squared_error: 2.7514 - val_y2_output_root_mean_squared_error: 3.3505
# Epoch 21/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.1048 - y1_output_loss: 5.0949 - y2_output_loss: 7.9499 - y1_output_root_mean_squared_error: 2.2569 - y2_output_root_mean_squared_error: 2.8304 - val_loss: 11.9866 - val_y1_output_loss: 5.2913 - val_y2_output_loss: 6.7021 - val_y1_output_root_mean_squared_error: 2.3076 - val_y2_output_root_mean_squared_error: 2.5810
# Epoch 22/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.1319 - y1_output_loss: 4.8072 - y2_output_loss: 8.4363 - y1_output_root_mean_squared_error: 2.1861 - y2_output_root_mean_squared_error: 2.8901 - val_loss: 36.6455 - val_y1_output_loss: 11.8735 - val_y2_output_loss: 25.4721 - val_y1_output_root_mean_squared_error: 3.3986 - val_y2_output_root_mean_squared_error: 5.0095
# Epoch 23/500
# 614/614 [==============================] - 0s 147us/sample - loss: 13.9913 - y1_output_loss: 5.0727 - y2_output_loss: 8.9088 - y1_output_root_mean_squared_error: 2.2597 - y2_output_root_mean_squared_error: 2.9808 - val_loss: 11.9299 - val_y1_output_loss: 5.5631 - val_y2_output_loss: 6.6172 - val_y1_output_root_mean_squared_error: 2.3365 - val_y2_output_root_mean_squared_error: 2.5438
# Epoch 24/500
# 614/614 [==============================] - 0s 176us/sample - loss: 11.4198 - y1_output_loss: 4.3826 - y2_output_loss: 7.1491 - y1_output_root_mean_squared_error: 2.0963 - y2_output_root_mean_squared_error: 2.6505 - val_loss: 38.1671 - val_y1_output_loss: 9.7344 - val_y2_output_loss: 28.7144 - val_y1_output_root_mean_squared_error: 3.1090 - val_y2_output_root_mean_squared_error: 5.3387
# Epoch 25/500
# 614/614 [==============================] - 0s 148us/sample - loss: 13.1841 - y1_output_loss: 4.5475 - y2_output_loss: 8.6127 - y1_output_root_mean_squared_error: 2.1409 - y2_output_root_mean_squared_error: 2.9327 - val_loss: 10.8204 - val_y1_output_loss: 4.5019 - val_y2_output_loss: 6.2454 - val_y1_output_root_mean_squared_error: 2.1269 - val_y2_output_root_mean_squared_error: 2.5093
# Epoch 26/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.6682 - y1_output_loss: 4.8720 - y2_output_loss: 8.8810 - y1_output_root_mean_squared_error: 2.2127 - y2_output_root_mean_squared_error: 2.9617 - val_loss: 26.9146 - val_y1_output_loss: 6.7271 - val_y2_output_loss: 19.9548 - val_y1_output_root_mean_squared_error: 2.6174 - val_y2_output_root_mean_squared_error: 4.4792
# Epoch 27/500
# 614/614 [==============================] - 0s 144us/sample - loss: 11.5745 - y1_output_loss: 4.0760 - y2_output_loss: 7.4133 - y1_output_root_mean_squared_error: 2.0232 - y2_output_root_mean_squared_error: 2.7352 - val_loss: 9.8686 - val_y1_output_loss: 4.2416 - val_y2_output_loss: 5.8677 - val_y1_output_root_mean_squared_error: 2.0399 - val_y2_output_root_mean_squared_error: 2.3890
# Epoch 28/500
# 614/614 [==============================] - 0s 141us/sample - loss: 11.4533 - y1_output_loss: 3.9742 - y2_output_loss: 7.4124 - y1_output_root_mean_squared_error: 2.0012 - y2_output_root_mean_squared_error: 2.7292 - val_loss: 9.8561 - val_y1_output_loss: 4.1505 - val_y2_output_loss: 5.8419 - val_y1_output_root_mean_squared_error: 2.0216 - val_y2_output_root_mean_squared_error: 2.4019
# Epoch 29/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.6062 - y1_output_loss: 3.3992 - y2_output_loss: 6.2465 - y1_output_root_mean_squared_error: 1.8485 - y2_output_root_mean_squared_error: 2.4878 - val_loss: 10.0421 - val_y1_output_loss: 4.6286 - val_y2_output_loss: 5.7613 - val_y1_output_root_mean_squared_error: 2.1180 - val_y2_output_root_mean_squared_error: 2.3571
# Epoch 30/500
# 614/614 [==============================] - 0s 154us/sample - loss: 11.5290 - y1_output_loss: 3.6471 - y2_output_loss: 7.8680 - y1_output_root_mean_squared_error: 1.9149 - y2_output_root_mean_squared_error: 2.8040 - val_loss: 9.4858 - val_y1_output_loss: 4.0299 - val_y2_output_loss: 5.4826 - val_y1_output_root_mean_squared_error: 2.0060 - val_y2_output_root_mean_squared_error: 2.3371
# Epoch 31/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.9904 - y1_output_loss: 3.2378 - y2_output_loss: 5.7079 - y1_output_root_mean_squared_error: 1.8036 - y2_output_root_mean_squared_error: 2.3953 - val_loss: 9.8324 - val_y1_output_loss: 3.9358 - val_y2_output_loss: 6.1766 - val_y1_output_root_mean_squared_error: 1.9469 - val_y2_output_root_mean_squared_error: 2.4580
# Epoch 32/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.7424 - y1_output_loss: 4.1209 - y2_output_loss: 8.5578 - y1_output_root_mean_squared_error: 2.0359 - y2_output_root_mean_squared_error: 2.9321 - val_loss: 8.2490 - val_y1_output_loss: 3.5204 - val_y2_output_loss: 4.9108 - val_y1_output_root_mean_squared_error: 1.8557 - val_y2_output_root_mean_squared_error: 2.1921
# Epoch 33/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.0878 - y1_output_loss: 3.3468 - y2_output_loss: 6.6945 - y1_output_root_mean_squared_error: 1.8351 - y2_output_root_mean_squared_error: 2.5923 - val_loss: 13.3200 - val_y1_output_loss: 5.9563 - val_y2_output_loss: 7.6923 - val_y1_output_root_mean_squared_error: 2.3979 - val_y2_output_root_mean_squared_error: 2.7514
# Epoch 34/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.2343 - y1_output_loss: 2.7274 - y2_output_loss: 4.5489 - y1_output_root_mean_squared_error: 1.6493 - y2_output_root_mean_squared_error: 2.1247 - val_loss: 7.9839 - val_y1_output_loss: 3.1061 - val_y2_output_loss: 4.9268 - val_y1_output_root_mean_squared_error: 1.7594 - val_y2_output_root_mean_squared_error: 2.2109
# Epoch 35/500
# 614/614 [==============================] - 0s 143us/sample - loss: 10.4449 - y1_output_loss: 3.4604 - y2_output_loss: 7.0526 - y1_output_root_mean_squared_error: 1.8632 - y2_output_root_mean_squared_error: 2.6407 - val_loss: 10.3887 - val_y1_output_loss: 4.0061 - val_y2_output_loss: 6.4072 - val_y1_output_root_mean_squared_error: 2.0007 - val_y2_output_root_mean_squared_error: 2.5271
# Epoch 36/500
# 614/614 [==============================] - 0s 143us/sample - loss: 13.7322 - y1_output_loss: 3.9065 - y2_output_loss: 9.7499 - y1_output_root_mean_squared_error: 1.9852 - y2_output_root_mean_squared_error: 3.1291 - val_loss: 8.9039 - val_y1_output_loss: 3.1577 - val_y2_output_loss: 5.9529 - val_y1_output_root_mean_squared_error: 1.7596 - val_y2_output_root_mean_squared_error: 2.4099
# Epoch 37/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.6857 - y1_output_loss: 2.6317 - y2_output_loss: 5.0628 - y1_output_root_mean_squared_error: 1.6190 - y2_output_root_mean_squared_error: 2.2505 - val_loss: 16.5640 - val_y1_output_loss: 4.2869 - val_y2_output_loss: 12.5388 - val_y1_output_root_mean_squared_error: 2.0464 - val_y2_output_root_mean_squared_error: 3.5180
# Epoch 38/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.1825 - y1_output_loss: 3.4201 - y2_output_loss: 6.6667 - y1_output_root_mean_squared_error: 1.8582 - y2_output_root_mean_squared_error: 2.5942 - val_loss: 7.4423 - val_y1_output_loss: 2.8791 - val_y2_output_loss: 4.7490 - val_y1_output_root_mean_squared_error: 1.6683 - val_y2_output_root_mean_squared_error: 2.1585
# Epoch 39/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.5476 - y1_output_loss: 2.2752 - y2_output_loss: 4.3655 - y1_output_root_mean_squared_error: 1.4973 - y2_output_root_mean_squared_error: 2.0750 - val_loss: 11.8549 - val_y1_output_loss: 4.4301 - val_y2_output_loss: 7.7538 - val_y1_output_root_mean_squared_error: 2.0622 - val_y2_output_root_mean_squared_error: 2.7572
# Epoch 40/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.5450 - y1_output_loss: 2.3959 - y2_output_loss: 5.1518 - y1_output_root_mean_squared_error: 1.5537 - y2_output_root_mean_squared_error: 2.2652 - val_loss: 13.1776 - val_y1_output_loss: 3.0327 - val_y2_output_loss: 10.0619 - val_y1_output_root_mean_squared_error: 1.7455 - val_y2_output_root_mean_squared_error: 3.1829
# Epoch 41/500
# 614/614 [==============================] - 0s 157us/sample - loss: 9.5938 - y1_output_loss: 3.0822 - y2_output_loss: 6.4569 - y1_output_root_mean_squared_error: 1.7579 - y2_output_root_mean_squared_error: 2.5502 - val_loss: 6.7072 - val_y1_output_loss: 2.2284 - val_y2_output_loss: 4.5845 - val_y1_output_root_mean_squared_error: 1.4691 - val_y2_output_root_mean_squared_error: 2.1328
# Epoch 42/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.6447 - y1_output_loss: 2.1362 - y2_output_loss: 4.5072 - y1_output_root_mean_squared_error: 1.4662 - y2_output_root_mean_squared_error: 2.1202 - val_loss: 10.1357 - val_y1_output_loss: 2.4486 - val_y2_output_loss: 7.8371 - val_y1_output_root_mean_squared_error: 1.5455 - val_y2_output_root_mean_squared_error: 2.7833
# Epoch 43/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.6051 - y1_output_loss: 2.1000 - y2_output_loss: 4.4912 - y1_output_root_mean_squared_error: 1.4478 - y2_output_root_mean_squared_error: 2.1234 - val_loss: 8.6053 - val_y1_output_loss: 3.4040 - val_y2_output_loss: 5.4619 - val_y1_output_root_mean_squared_error: 1.8054 - val_y2_output_root_mean_squared_error: 2.3121
# Epoch 44/500
# 614/614 [==============================] - 0s 150us/sample - loss: 6.8664 - y1_output_loss: 2.2070 - y2_output_loss: 4.6981 - y1_output_root_mean_squared_error: 1.4899 - y2_output_root_mean_squared_error: 2.1556 - val_loss: 6.3415 - val_y1_output_loss: 2.0175 - val_y2_output_loss: 4.4093 - val_y1_output_root_mean_squared_error: 1.4012 - val_y2_output_root_mean_squared_error: 2.0924
# Epoch 45/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.5720 - y1_output_loss: 2.4946 - y2_output_loss: 6.0613 - y1_output_root_mean_squared_error: 1.5838 - y2_output_root_mean_squared_error: 2.4624 - val_loss: 7.9659 - val_y1_output_loss: 2.7220 - val_y2_output_loss: 5.5565 - val_y1_output_root_mean_squared_error: 1.6126 - val_y2_output_root_mean_squared_error: 2.3163
# Epoch 46/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.6834 - y1_output_loss: 2.1658 - y2_output_loss: 4.5893 - y1_output_root_mean_squared_error: 1.4653 - y2_output_root_mean_squared_error: 2.1299 - val_loss: 7.8306 - val_y1_output_loss: 2.4009 - val_y2_output_loss: 5.4951 - val_y1_output_root_mean_squared_error: 1.5323 - val_y2_output_root_mean_squared_error: 2.3415
# Epoch 47/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.1871 - y1_output_loss: 2.1941 - y2_output_loss: 4.9545 - y1_output_root_mean_squared_error: 1.4879 - y2_output_root_mean_squared_error: 2.2301 - val_loss: 8.5063 - val_y1_output_loss: 2.3095 - val_y2_output_loss: 6.2119 - val_y1_output_root_mean_squared_error: 1.5191 - val_y2_output_root_mean_squared_error: 2.4897
# Epoch 48/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.2589 - y1_output_loss: 1.9816 - y2_output_loss: 4.2485 - y1_output_root_mean_squared_error: 1.4077 - y2_output_root_mean_squared_error: 2.0682 - val_loss: 7.5557 - val_y1_output_loss: 2.5737 - val_y2_output_loss: 5.2691 - val_y1_output_root_mean_squared_error: 1.5653 - val_y2_output_root_mean_squared_error: 2.2595
# Epoch 49/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.4911 - y1_output_loss: 2.4050 - y2_output_loss: 5.0511 - y1_output_root_mean_squared_error: 1.5536 - y2_output_root_mean_squared_error: 2.2533 - val_loss: 9.5015 - val_y1_output_loss: 3.0305 - val_y2_output_loss: 6.4080 - val_y1_output_root_mean_squared_error: 1.7382 - val_y2_output_root_mean_squared_error: 2.5456
# Epoch 50/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.6970 - y1_output_loss: 2.0616 - y2_output_loss: 4.7364 - y1_output_root_mean_squared_error: 1.4405 - y2_output_root_mean_squared_error: 2.1499 - val_loss: 9.4702 - val_y1_output_loss: 2.5660 - val_y2_output_loss: 7.2022 - val_y1_output_root_mean_squared_error: 1.5689 - val_y2_output_root_mean_squared_error: 2.6474
# Epoch 51/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.9856 - y1_output_loss: 1.8179 - y2_output_loss: 4.1832 - y1_output_root_mean_squared_error: 1.3542 - y2_output_root_mean_squared_error: 2.0375 - val_loss: 10.8991 - val_y1_output_loss: 2.2803 - val_y2_output_loss: 8.6344 - val_y1_output_root_mean_squared_error: 1.5050 - val_y2_output_root_mean_squared_error: 2.9384
# Epoch 52/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.7178 - y1_output_loss: 1.8623 - y2_output_loss: 3.9094 - y1_output_root_mean_squared_error: 1.3686 - y2_output_root_mean_squared_error: 1.9608 - val_loss: 16.3490 - val_y1_output_loss: 3.0161 - val_y2_output_loss: 13.2743 - val_y1_output_root_mean_squared_error: 1.7342 - val_y2_output_root_mean_squared_error: 3.6526
# Epoch 53/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.3132 - y1_output_loss: 1.9162 - y2_output_loss: 4.4246 - y1_output_root_mean_squared_error: 1.3886 - y2_output_root_mean_squared_error: 2.0940 - val_loss: 40.4039 - val_y1_output_loss: 6.3748 - val_y2_output_loss: 34.0583 - val_y1_output_root_mean_squared_error: 2.5262 - val_y2_output_root_mean_squared_error: 5.8329
# Epoch 54/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1372 - y1_output_loss: 1.9047 - y2_output_loss: 4.2376 - y1_output_root_mean_squared_error: 1.3734 - y2_output_root_mean_squared_error: 2.0618 - val_loss: 7.0500 - val_y1_output_loss: 2.3235 - val_y2_output_loss: 4.6992 - val_y1_output_root_mean_squared_error: 1.5178 - val_y2_output_root_mean_squared_error: 2.1786
# Epoch 55/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.5305 - y1_output_loss: 1.4130 - y2_output_loss: 3.0849 - y1_output_root_mean_squared_error: 1.1915 - y2_output_root_mean_squared_error: 1.7638 - val_loss: 5.8281 - val_y1_output_loss: 1.8516 - val_y2_output_loss: 4.0330 - val_y1_output_root_mean_squared_error: 1.3510 - val_y2_output_root_mean_squared_error: 2.0007
# Epoch 56/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.9880 - y1_output_loss: 1.6081 - y2_output_loss: 3.3849 - y1_output_root_mean_squared_error: 1.2628 - y2_output_root_mean_squared_error: 1.8421 - val_loss: 7.9696 - val_y1_output_loss: 2.5263 - val_y2_output_loss: 5.4404 - val_y1_output_root_mean_squared_error: 1.5871 - val_y2_output_root_mean_squared_error: 2.3347
# Epoch 57/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.1326 - y1_output_loss: 1.6682 - y2_output_loss: 4.4525 - y1_output_root_mean_squared_error: 1.2971 - y2_output_root_mean_squared_error: 2.1095 - val_loss: 7.3065 - val_y1_output_loss: 1.7396 - val_y2_output_loss: 5.6311 - val_y1_output_root_mean_squared_error: 1.3133 - val_y2_output_root_mean_squared_error: 2.3626
# Epoch 58/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.5164 - y1_output_loss: 2.3804 - y2_output_loss: 5.1266 - y1_output_root_mean_squared_error: 1.5402 - y2_output_root_mean_squared_error: 2.2681 - val_loss: 7.6826 - val_y1_output_loss: 2.8130 - val_y2_output_loss: 4.9150 - val_y1_output_root_mean_squared_error: 1.6742 - val_y2_output_root_mean_squared_error: 2.2090
# Epoch 59/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.8481 - y1_output_loss: 2.1255 - y2_output_loss: 4.7557 - y1_output_root_mean_squared_error: 1.4636 - y2_output_root_mean_squared_error: 2.1693 - val_loss: 9.6203 - val_y1_output_loss: 2.7482 - val_y2_output_loss: 6.8558 - val_y1_output_root_mean_squared_error: 1.6583 - val_y2_output_root_mean_squared_error: 2.6211
# Epoch 60/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.9870 - y1_output_loss: 1.7197 - y2_output_loss: 4.2509 - y1_output_root_mean_squared_error: 1.3075 - y2_output_root_mean_squared_error: 2.0682 - val_loss: 11.7057 - val_y1_output_loss: 2.9942 - val_y2_output_loss: 8.6873 - val_y1_output_root_mean_squared_error: 1.7331 - val_y2_output_root_mean_squared_error: 2.9499
# Epoch 61/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.6075 - y1_output_loss: 1.6271 - y2_output_loss: 3.9620 - y1_output_root_mean_squared_error: 1.2811 - y2_output_root_mean_squared_error: 1.9916 - val_loss: 7.6497 - val_y1_output_loss: 1.6879 - val_y2_output_loss: 5.9738 - val_y1_output_root_mean_squared_error: 1.2884 - val_y2_output_root_mean_squared_error: 2.4474
# Epoch 62/500
# 614/614 [==============================] - 0s 157us/sample - loss: 4.5950 - y1_output_loss: 1.3944 - y2_output_loss: 3.1764 - y1_output_root_mean_squared_error: 1.1812 - y2_output_root_mean_squared_error: 1.7888 - val_loss: 5.1899 - val_y1_output_loss: 1.5919 - val_y2_output_loss: 3.6235 - val_y1_output_root_mean_squared_error: 1.2518 - val_y2_output_root_mean_squared_error: 1.9034
# Epoch 63/500
# 614/614 [==============================] - 0s 155us/sample - loss: 5.0804 - y1_output_loss: 1.3517 - y2_output_loss: 3.7103 - y1_output_root_mean_squared_error: 1.1641 - y2_output_root_mean_squared_error: 1.9301 - val_loss: 8.2251 - val_y1_output_loss: 3.1285 - val_y2_output_loss: 5.0294 - val_y1_output_root_mean_squared_error: 1.7792 - val_y2_output_root_mean_squared_error: 2.2493
# Epoch 64/500
# 614/614 [==============================] - 0s 155us/sample - loss: 5.3545 - y1_output_loss: 1.7649 - y2_output_loss: 3.6249 - y1_output_root_mean_squared_error: 1.3269 - y2_output_root_mean_squared_error: 1.8958 - val_loss: 16.2580 - val_y1_output_loss: 4.0898 - val_y2_output_loss: 11.8868 - val_y1_output_root_mean_squared_error: 2.0489 - val_y2_output_root_mean_squared_error: 3.4728
# Epoch 65/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.2635 - y1_output_loss: 1.4956 - y2_output_loss: 3.7350 - y1_output_root_mean_squared_error: 1.2250 - y2_output_root_mean_squared_error: 1.9398 - val_loss: 5.2867 - val_y1_output_loss: 1.6882 - val_y2_output_loss: 3.6431 - val_y1_output_root_mean_squared_error: 1.2919 - val_y2_output_root_mean_squared_error: 1.9020
# Epoch 66/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.0692 - y1_output_loss: 1.1539 - y2_output_loss: 2.9052 - y1_output_root_mean_squared_error: 1.0728 - y2_output_root_mean_squared_error: 1.7083 - val_loss: 7.4145 - val_y1_output_loss: 1.8351 - val_y2_output_loss: 5.6046 - val_y1_output_root_mean_squared_error: 1.3456 - val_y2_output_root_mean_squared_error: 2.3672
# Epoch 67/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.3035 - y1_output_loss: 1.0768 - y2_output_loss: 3.2082 - y1_output_root_mean_squared_error: 1.0330 - y2_output_root_mean_squared_error: 1.7990 - val_loss: 5.2225 - val_y1_output_loss: 1.7262 - val_y2_output_loss: 3.5195 - val_y1_output_root_mean_squared_error: 1.3117 - val_y2_output_root_mean_squared_error: 1.8713
# Epoch 68/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9805 - y1_output_loss: 1.1046 - y2_output_loss: 2.9669 - y1_output_root_mean_squared_error: 1.0404 - y2_output_root_mean_squared_error: 1.7024 - val_loss: 20.0374 - val_y1_output_loss: 5.6741 - val_y2_output_loss: 14.0487 - val_y1_output_root_mean_squared_error: 2.4118 - val_y2_output_root_mean_squared_error: 3.7710
# Epoch 69/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.4422 - y1_output_loss: 1.0333 - y2_output_loss: 2.3967 - y1_output_root_mean_squared_error: 1.0181 - y2_output_root_mean_squared_error: 1.5510 - val_loss: 8.4288 - val_y1_output_loss: 1.9838 - val_y2_output_loss: 6.4966 - val_y1_output_root_mean_squared_error: 1.4078 - val_y2_output_root_mean_squared_error: 2.5391
# Epoch 70/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.1462 - y1_output_loss: 1.9113 - y2_output_loss: 4.2160 - y1_output_root_mean_squared_error: 1.3847 - y2_output_root_mean_squared_error: 2.0564 - val_loss: 6.5187 - val_y1_output_loss: 1.8354 - val_y2_output_loss: 4.7120 - val_y1_output_root_mean_squared_error: 1.3536 - val_y2_output_root_mean_squared_error: 2.1648
# Epoch 71/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.6028 - y1_output_loss: 1.0034 - y2_output_loss: 2.5734 - y1_output_root_mean_squared_error: 1.0063 - y2_output_root_mean_squared_error: 1.6094 - val_loss: 4.0703 - val_y1_output_loss: 0.9893 - val_y2_output_loss: 3.0475 - val_y1_output_root_mean_squared_error: 1.0010 - val_y2_output_root_mean_squared_error: 1.7516
# Epoch 72/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.2706 - y1_output_loss: 1.0321 - y2_output_loss: 3.2195 - y1_output_root_mean_squared_error: 1.0201 - y2_output_root_mean_squared_error: 1.7973 - val_loss: 7.6555 - val_y1_output_loss: 2.5873 - val_y2_output_loss: 4.9576 - val_y1_output_root_mean_squared_error: 1.6218 - val_y2_output_root_mean_squared_error: 2.2417
# Epoch 73/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.8655 - y1_output_loss: 0.9940 - y2_output_loss: 2.8587 - y1_output_root_mean_squared_error: 0.9970 - y2_output_root_mean_squared_error: 1.6945 - val_loss: 6.3302 - val_y1_output_loss: 2.1691 - val_y2_output_loss: 4.1055 - val_y1_output_root_mean_squared_error: 1.4799 - val_y2_output_root_mean_squared_error: 2.0348
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.0223 - y1_output_loss: 1.3992 - y2_output_loss: 3.5843 - y1_output_root_mean_squared_error: 1.1882 - y2_output_root_mean_squared_error: 1.9001 - val_loss: 4.9454 - val_y1_output_loss: 0.8723 - val_y2_output_loss: 4.1035 - val_y1_output_root_mean_squared_error: 0.9325 - val_y2_output_root_mean_squared_error: 2.0189
# Epoch 75/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.4369 - y1_output_loss: 0.8755 - y2_output_loss: 2.5663 - y1_output_root_mean_squared_error: 0.9331 - y2_output_root_mean_squared_error: 1.6019 - val_loss: 12.1771 - val_y1_output_loss: 4.4879 - val_y2_output_loss: 7.5202 - val_y1_output_root_mean_squared_error: 2.1417 - val_y2_output_root_mean_squared_error: 2.7551
# Epoch 76/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.6260 - y1_output_loss: 0.9360 - y2_output_loss: 2.6758 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.6391 - val_loss: 3.9063 - val_y1_output_loss: 0.7983 - val_y2_output_loss: 3.0536 - val_y1_output_root_mean_squared_error: 0.9048 - val_y2_output_root_mean_squared_error: 1.7572
# Epoch 77/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.8361 - y1_output_loss: 1.4784 - y2_output_loss: 3.3269 - y1_output_root_mean_squared_error: 1.2193 - y2_output_root_mean_squared_error: 1.8301 - val_loss: 4.0206 - val_y1_output_loss: 0.8482 - val_y2_output_loss: 3.1313 - val_y1_output_root_mean_squared_error: 0.9304 - val_y2_output_root_mean_squared_error: 1.7762
# Epoch 78/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9509 - y1_output_loss: 0.7870 - y2_output_loss: 2.1413 - y1_output_root_mean_squared_error: 0.8894 - y2_output_root_mean_squared_error: 1.4697 - val_loss: 3.5600 - val_y1_output_loss: 0.8772 - val_y2_output_loss: 2.6906 - val_y1_output_root_mean_squared_error: 0.9384 - val_y2_output_root_mean_squared_error: 1.6369
# Epoch 79/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.2112 - y1_output_loss: 0.9185 - y2_output_loss: 2.2645 - y1_output_root_mean_squared_error: 0.9617 - y2_output_root_mean_squared_error: 1.5121 - val_loss: 3.2527 - val_y1_output_loss: 0.5926 - val_y2_output_loss: 2.6328 - val_y1_output_root_mean_squared_error: 0.7801 - val_y2_output_root_mean_squared_error: 1.6261
# Epoch 80/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7411 - y1_output_loss: 1.0147 - y2_output_loss: 2.9152 - y1_output_root_mean_squared_error: 1.0067 - y2_output_root_mean_squared_error: 1.6515 - val_loss: 12.6732 - val_y1_output_loss: 1.8596 - val_y2_output_loss: 10.5871 - val_y1_output_root_mean_squared_error: 1.3749 - val_y2_output_root_mean_squared_error: 3.2837
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.4366 - y1_output_loss: 0.9808 - y2_output_loss: 2.5063 - y1_output_root_mean_squared_error: 0.9934 - y2_output_root_mean_squared_error: 1.5652 - val_loss: 7.0137 - val_y1_output_loss: 1.7852 - val_y2_output_loss: 5.2152 - val_y1_output_root_mean_squared_error: 1.3341 - val_y2_output_root_mean_squared_error: 2.2878
# Epoch 82/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0812 - y1_output_loss: 0.7013 - y2_output_loss: 2.3627 - y1_output_root_mean_squared_error: 0.8340 - y2_output_root_mean_squared_error: 1.5446 - val_loss: 3.8380 - val_y1_output_loss: 0.8706 - val_y2_output_loss: 2.9089 - val_y1_output_root_mean_squared_error: 0.9427 - val_y2_output_root_mean_squared_error: 1.7173
# Epoch 83/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.3646 - y1_output_loss: 0.8906 - y2_output_loss: 2.4566 - y1_output_root_mean_squared_error: 0.9444 - y2_output_root_mean_squared_error: 1.5725 - val_loss: 4.2038 - val_y1_output_loss: 1.1508 - val_y2_output_loss: 2.9961 - val_y1_output_root_mean_squared_error: 1.0878 - val_y2_output_root_mean_squared_error: 1.7380
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5745 - y1_output_loss: 0.5842 - y2_output_loss: 1.9939 - y1_output_root_mean_squared_error: 0.7613 - y2_output_root_mean_squared_error: 1.4124 - val_loss: 3.6162 - val_y1_output_loss: 0.7880 - val_y2_output_loss: 2.8658 - val_y1_output_root_mean_squared_error: 0.8893 - val_y2_output_root_mean_squared_error: 1.6809
# Epoch 85/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.0105 - y1_output_loss: 1.0121 - y2_output_loss: 2.9876 - y1_output_root_mean_squared_error: 1.0075 - y2_output_root_mean_squared_error: 1.7307 - val_loss: 3.6913 - val_y1_output_loss: 0.7971 - val_y2_output_loss: 2.9568 - val_y1_output_root_mean_squared_error: 0.8902 - val_y2_output_root_mean_squared_error: 1.7026
# Epoch 86/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6302 - y1_output_loss: 0.5533 - y2_output_loss: 2.1021 - y1_output_root_mean_squared_error: 0.7439 - y2_output_root_mean_squared_error: 1.4411 - val_loss: 4.2420 - val_y1_output_loss: 1.3066 - val_y2_output_loss: 2.8770 - val_y1_output_root_mean_squared_error: 1.1577 - val_y2_output_root_mean_squared_error: 1.7035
# Epoch 87/500
# 614/614 [==============================] - 0s 165us/sample - loss: 5.0215 - y1_output_loss: 1.4319 - y2_output_loss: 3.5820 - y1_output_root_mean_squared_error: 1.1968 - y2_output_root_mean_squared_error: 1.8945 - val_loss: 4.9698 - val_y1_output_loss: 1.5590 - val_y2_output_loss: 3.3049 - val_y1_output_root_mean_squared_error: 1.2694 - val_y2_output_root_mean_squared_error: 1.8326
# Epoch 88/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.1213 - y1_output_loss: 0.7558 - y2_output_loss: 2.4046 - y1_output_root_mean_squared_error: 0.8577 - y2_output_root_mean_squared_error: 1.5445 - val_loss: 8.5494 - val_y1_output_loss: 3.1188 - val_y2_output_loss: 5.2582 - val_y1_output_root_mean_squared_error: 1.7912 - val_y2_output_root_mean_squared_error: 2.3111
# Epoch 89/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.7912 - y1_output_loss: 2.1510 - y2_output_loss: 5.6017 - y1_output_root_mean_squared_error: 1.4709 - y2_output_root_mean_squared_error: 2.3723 - val_loss: 4.1525 - val_y1_output_loss: 1.2238 - val_y2_output_loss: 2.9238 - val_y1_output_root_mean_squared_error: 1.1124 - val_y2_output_root_mean_squared_error: 1.7073
# Epoch 90/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6409 - y1_output_loss: 0.9839 - y2_output_loss: 2.6376 - y1_output_root_mean_squared_error: 0.9965 - y2_output_root_mean_squared_error: 1.6272 - val_loss: 3.5702 - val_y1_output_loss: 0.8635 - val_y2_output_loss: 2.7051 - val_y1_output_root_mean_squared_error: 0.9444 - val_y2_output_root_mean_squared_error: 1.6366
# Epoch 91/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5872 - y1_output_loss: 0.6826 - y2_output_loss: 1.9039 - y1_output_root_mean_squared_error: 0.8302 - y2_output_root_mean_squared_error: 1.3777 - val_loss: 4.2571 - val_y1_output_loss: 0.6402 - val_y2_output_loss: 3.6650 - val_y1_output_root_mean_squared_error: 0.8069 - val_y2_output_root_mean_squared_error: 1.8990
# Epoch 92/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6371 - y1_output_loss: 0.5664 - y2_output_loss: 2.0544 - y1_output_root_mean_squared_error: 0.7518 - y2_output_root_mean_squared_error: 1.4394 - val_loss: 4.0484 - val_y1_output_loss: 0.7336 - val_y2_output_loss: 3.3234 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.8172
# Epoch 93/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.6243 - y1_output_loss: 0.6536 - y2_output_loss: 1.9865 - y1_output_root_mean_squared_error: 0.8072 - y2_output_root_mean_squared_error: 1.4046 - val_loss: 4.3280 - val_y1_output_loss: 0.9088 - val_y2_output_loss: 3.4588 - val_y1_output_root_mean_squared_error: 0.9588 - val_y2_output_root_mean_squared_error: 1.8462
# Epoch 94/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.2197 - y1_output_loss: 0.7328 - y2_output_loss: 2.4655 - y1_output_root_mean_squared_error: 0.8570 - y2_output_root_mean_squared_error: 1.5765 - val_loss: 3.8809 - val_y1_output_loss: 1.0915 - val_y2_output_loss: 2.7385 - val_y1_output_root_mean_squared_error: 1.0525 - val_y2_output_root_mean_squared_error: 1.6653
# Epoch 95/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.3367 - y1_output_loss: 0.5863 - y2_output_loss: 1.7484 - y1_output_root_mean_squared_error: 0.7638 - y2_output_root_mean_squared_error: 1.3241 - val_loss: 4.5115 - val_y1_output_loss: 1.5817 - val_y2_output_loss: 2.8669 - val_y1_output_root_mean_squared_error: 1.2747 - val_y2_output_root_mean_squared_error: 1.6991
# Epoch 96/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.0233 - y1_output_loss: 0.6663 - y2_output_loss: 2.3292 - y1_output_root_mean_squared_error: 0.8195 - y2_output_root_mean_squared_error: 1.5336 - val_loss: 2.9728 - val_y1_output_loss: 0.7352 - val_y2_output_loss: 2.2305 - val_y1_output_root_mean_squared_error: 0.8652 - val_y2_output_root_mean_squared_error: 1.4914
# Epoch 97/500
# 614/614 [==============================] - 0s 144us/sample - loss: 17.6182 - y1_output_loss: 5.8539 - y2_output_loss: 11.6185 - y1_output_root_mean_squared_error: 2.4302 - y2_output_root_mean_squared_error: 3.4223 - val_loss: 3.9216 - val_y1_output_loss: 1.0180 - val_y2_output_loss: 2.9832 - val_y1_output_root_mean_squared_error: 1.0076 - val_y2_output_root_mean_squared_error: 1.7048
# Epoch 98/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.8444 - y1_output_loss: 0.8821 - y2_output_loss: 3.3836 - y1_output_root_mean_squared_error: 0.9012 - y2_output_root_mean_squared_error: 1.7413 - val_loss: 79.6141 - val_y1_output_loss: 22.0896 - val_y2_output_loss: 56.3587 - val_y1_output_root_mean_squared_error: 4.7467 - val_y2_output_root_mean_squared_error: 7.5553
# Epoch 99/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0928 - y1_output_loss: 1.0690 - y2_output_loss: 2.9961 - y1_output_root_mean_squared_error: 1.0385 - y2_output_root_mean_squared_error: 1.7362 - val_loss: 3.3318 - val_y1_output_loss: 0.6355 - val_y2_output_loss: 2.6210 - val_y1_output_root_mean_squared_error: 0.8089 - val_y2_output_root_mean_squared_error: 1.6363
# Epoch 100/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.3431 - y1_output_loss: 0.5328 - y2_output_loss: 1.7989 - y1_output_root_mean_squared_error: 0.7296 - y2_output_root_mean_squared_error: 1.3457 - val_loss: 3.4702 - val_y1_output_loss: 0.9233 - val_y2_output_loss: 2.5107 - val_y1_output_root_mean_squared_error: 0.9689 - val_y2_output_root_mean_squared_error: 1.5910
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1120 - y1_output_loss: 0.7475 - y2_output_loss: 2.3596 - y1_output_root_mean_squared_error: 0.8572 - y2_output_root_mean_squared_error: 1.5418 - val_loss: 5.2233 - val_y1_output_loss: 1.6409 - val_y2_output_loss: 3.4730 - val_y1_output_root_mean_squared_error: 1.3002 - val_y2_output_root_mean_squared_error: 1.8796
# Epoch 102/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5540 - y1_output_loss: 0.5410 - y2_output_loss: 2.0716 - y1_output_root_mean_squared_error: 0.7380 - y2_output_root_mean_squared_error: 1.4175 - val_loss: 8.4259 - val_y1_output_loss: 1.2735 - val_y2_output_loss: 6.9847 - val_y1_output_root_mean_squared_error: 1.1381 - val_y2_output_root_mean_squared_error: 2.6703
# Epoch 103/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.2841 - y1_output_loss: 1.2394 - y2_output_loss: 3.0189 - y1_output_root_mean_squared_error: 1.1183 - y2_output_root_mean_squared_error: 1.7417 - val_loss: 4.0829 - val_y1_output_loss: 0.9341 - val_y2_output_loss: 3.1192 - val_y1_output_root_mean_squared_error: 0.9822 - val_y2_output_root_mean_squared_error: 1.7658
# Epoch 104/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1938 - y1_output_loss: 0.7697 - y2_output_loss: 2.4029 - y1_output_root_mean_squared_error: 0.8802 - y2_output_root_mean_squared_error: 1.5553 - val_loss: 2.7743 - val_y1_output_loss: 0.5464 - val_y2_output_loss: 2.2128 - val_y1_output_root_mean_squared_error: 0.7472 - val_y2_output_root_mean_squared_error: 1.4886
# Epoch 105/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4030 - y1_output_loss: 0.5689 - y2_output_loss: 1.8163 - y1_output_root_mean_squared_error: 0.7574 - y2_output_root_mean_squared_error: 1.3526 - val_loss: 2.8113 - val_y1_output_loss: 0.4935 - val_y2_output_loss: 2.2881 - val_y1_output_root_mean_squared_error: 0.7086 - val_y2_output_root_mean_squared_error: 1.5196
# Epoch 106/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.8435 - y1_output_loss: 0.5715 - y2_output_loss: 2.2454 - y1_output_root_mean_squared_error: 0.7593 - y2_output_root_mean_squared_error: 1.5057 - val_loss: 3.0053 - val_y1_output_loss: 0.5975 - val_y2_output_loss: 2.3576 - val_y1_output_root_mean_squared_error: 0.7822 - val_y2_output_root_mean_squared_error: 1.5471
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.3302 - y1_output_loss: 0.5684 - y2_output_loss: 1.7805 - y1_output_root_mean_squared_error: 0.7401 - y2_output_root_mean_squared_error: 1.3351 - val_loss: 6.2195 - val_y1_output_loss: 2.2308 - val_y2_output_loss: 4.0018 - val_y1_output_root_mean_squared_error: 1.4858 - val_y2_output_root_mean_squared_error: 2.0030
# Epoch 108/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.4679 - y1_output_loss: 0.5244 - y2_output_loss: 1.9347 - y1_output_root_mean_squared_error: 0.7231 - y2_output_root_mean_squared_error: 1.3946 - val_loss: 3.4594 - val_y1_output_loss: 0.7811 - val_y2_output_loss: 2.6110 - val_y1_output_root_mean_squared_error: 0.8971 - val_y2_output_root_mean_squared_error: 1.6293
# Epoch 109/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.7780 - y1_output_loss: 0.6261 - y2_output_loss: 2.1884 - y1_output_root_mean_squared_error: 0.7894 - y2_output_root_mean_squared_error: 1.4679 - val_loss: 21.5105 - val_y1_output_loss: 2.8828 - val_y2_output_loss: 18.5735 - val_y1_output_root_mean_squared_error: 1.7175 - val_y2_output_root_mean_squared_error: 4.3082
# Epoch 110/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.3771 - y1_output_loss: 0.5447 - y2_output_loss: 1.8281 - y1_output_root_mean_squared_error: 0.7399 - y2_output_root_mean_squared_error: 1.3527 - val_loss: 5.6724 - val_y1_output_loss: 0.6093 - val_y2_output_loss: 5.1226 - val_y1_output_root_mean_squared_error: 0.7838 - val_y2_output_root_mean_squared_error: 2.2490
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.3006 - y1_output_loss: 0.5192 - y2_output_loss: 1.7666 - y1_output_root_mean_squared_error: 0.7193 - y2_output_root_mean_squared_error: 1.3354 - val_loss: 3.2318 - val_y1_output_loss: 0.8256 - val_y2_output_loss: 2.3783 - val_y1_output_root_mean_squared_error: 0.9109 - val_y2_output_root_mean_squared_error: 1.5499
# Epoch 112/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.7237 - y1_output_loss: 2.5201 - y2_output_loss: 5.1317 - y1_output_root_mean_squared_error: 1.5949 - y2_output_root_mean_squared_error: 2.2759 - val_loss: 2.7655 - val_y1_output_loss: 0.5272 - val_y2_output_loss: 2.2019 - val_y1_output_root_mean_squared_error: 0.7349 - val_y2_output_root_mean_squared_error: 1.4918
# Epoch 113/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6406 - y1_output_loss: 0.5846 - y2_output_loss: 2.0679 - y1_output_root_mean_squared_error: 0.7655 - y2_output_root_mean_squared_error: 1.4334 - val_loss: 9.3084 - val_y1_output_loss: 0.9040 - val_y2_output_loss: 8.5497 - val_y1_output_root_mean_squared_error: 0.9524 - val_y2_output_root_mean_squared_error: 2.8985
# Epoch 114/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0437 - y1_output_loss: 0.7146 - y2_output_loss: 2.3055 - y1_output_root_mean_squared_error: 0.8476 - y2_output_root_mean_squared_error: 1.5249 - val_loss: 3.0035 - val_y1_output_loss: 0.5763 - val_y2_output_loss: 2.4173 - val_y1_output_root_mean_squared_error: 0.7677 - val_y2_output_root_mean_squared_error: 1.5537
# Epoch 115/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1320 - y1_output_loss: 0.4576 - y2_output_loss: 1.6560 - y1_output_root_mean_squared_error: 0.6794 - y2_output_root_mean_squared_error: 1.2924 - val_loss: 2.6574 - val_y1_output_loss: 0.6346 - val_y2_output_loss: 2.0088 - val_y1_output_root_mean_squared_error: 0.8036 - val_y2_output_root_mean_squared_error: 1.4183
# Epoch 116/500
# 614/614 [==============================] - 0s 143us/sample - loss: 1.9907 - y1_output_loss: 0.4412 - y2_output_loss: 1.5544 - y1_output_root_mean_squared_error: 0.6661 - y2_output_root_mean_squared_error: 1.2438 - val_loss: 6.8151 - val_y1_output_loss: 0.4503 - val_y2_output_loss: 6.4922 - val_y1_output_root_mean_squared_error: 0.6748 - val_y2_output_root_mean_squared_error: 2.5219
# Epoch 117/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.9194 - y1_output_loss: 0.7358 - y2_output_loss: 2.1860 - y1_output_root_mean_squared_error: 0.8589 - y2_output_root_mean_squared_error: 1.4771 - val_loss: 9.9806 - val_y1_output_loss: 1.9369 - val_y2_output_loss: 7.9932 - val_y1_output_root_mean_squared_error: 1.4095 - val_y2_output_root_mean_squared_error: 2.8274
# Epoch 118/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.1110 - y1_output_loss: 0.7942 - y2_output_loss: 2.3236 - y1_output_root_mean_squared_error: 0.8909 - y2_output_root_mean_squared_error: 1.5223 - val_loss: 3.2657 - val_y1_output_loss: 0.5040 - val_y2_output_loss: 2.7380 - val_y1_output_root_mean_squared_error: 0.7215 - val_y2_output_root_mean_squared_error: 1.6568
# Epoch 119/500
# 614/614 [==============================] - 0s 143us/sample - loss: 1.8881 - y1_output_loss: 0.4225 - y2_output_loss: 1.4670 - y1_output_root_mean_squared_error: 0.6493 - y2_output_root_mean_squared_error: 1.2110 - val_loss: 6.3833 - val_y1_output_loss: 0.9798 - val_y2_output_loss: 5.2877 - val_y1_output_root_mean_squared_error: 0.9943 - val_y2_output_root_mean_squared_error: 2.3226
# Epoch 120/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.9915 - y1_output_loss: 0.4925 - y2_output_loss: 1.4916 - y1_output_root_mean_squared_error: 0.7049 - y2_output_root_mean_squared_error: 1.2226 - val_loss: 2.6831 - val_y1_output_loss: 0.4853 - val_y2_output_loss: 2.1456 - val_y1_output_root_mean_squared_error: 0.7048 - val_y2_output_root_mean_squared_error: 1.4787
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4466 - y1_output_loss: 0.1230 - y2_output_loss: 0.3206 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.5684 - val_loss: 0.9381 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 0.6786 - val_y1_output_root_mean_squared_error: 0.5237 - val_y2_output_root_mean_squared_error: 0.8148
# Epoch 462/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4763 - y1_output_loss: 0.1093 - y2_output_loss: 0.3653 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.6059 - val_loss: 0.9063 - val_y1_output_loss: 0.2647 - val_y2_output_loss: 0.6731 - val_y1_output_root_mean_squared_error: 0.5171 - val_y2_output_root_mean_squared_error: 0.7993
# Epoch 463/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3545 - y1_output_loss: 0.1086 - y2_output_loss: 0.2454 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.4958 - val_loss: 1.1713 - val_y1_output_loss: 0.3043 - val_y2_output_loss: 0.9127 - val_y1_output_root_mean_squared_error: 0.5581 - val_y2_output_root_mean_squared_error: 0.9272
# Epoch 464/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3904 - y1_output_loss: 0.1035 - y2_output_loss: 0.2849 - y1_output_root_mean_squared_error: 0.3205 - y2_output_root_mean_squared_error: 0.5363 - val_loss: 0.8692 - val_y1_output_loss: 0.2707 - val_y2_output_loss: 0.6068 - val_y1_output_root_mean_squared_error: 0.5295 - val_y2_output_root_mean_squared_error: 0.7673
# Epoch 465/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4360 - y1_output_loss: 0.1188 - y2_output_loss: 0.3140 - y1_output_root_mean_squared_error: 0.3459 - y2_output_root_mean_squared_error: 0.5625 - val_loss: 0.9408 - val_y1_output_loss: 0.2924 - val_y2_output_loss: 0.6650 - val_y1_output_root_mean_squared_error: 0.5475 - val_y2_output_root_mean_squared_error: 0.8006
# Epoch 466/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3725 - y1_output_loss: 0.1078 - y2_output_loss: 0.2623 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 0.9228 - val_y1_output_loss: 0.2696 - val_y2_output_loss: 0.6712 - val_y1_output_root_mean_squared_error: 0.5266 - val_y2_output_root_mean_squared_error: 0.8035
# Epoch 467/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3068 - y1_output_loss: 0.0986 - y2_output_loss: 0.2121 - y1_output_root_mean_squared_error: 0.3128 - y2_output_root_mean_squared_error: 0.4571 - val_loss: 1.2487 - val_y1_output_loss: 0.3134 - val_y2_output_loss: 0.9535 - val_y1_output_root_mean_squared_error: 0.5670 - val_y2_output_root_mean_squared_error: 0.9629
# Epoch 468/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3477 - y1_output_loss: 0.1082 - y2_output_loss: 0.2407 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4886 - val_loss: 1.0088 - val_y1_output_loss: 0.2698 - val_y2_output_loss: 0.7714 - val_y1_output_root_mean_squared_error: 0.5229 - val_y2_output_root_mean_squared_error: 0.8575
# Epoch 469/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4638 - y1_output_loss: 0.1326 - y2_output_loss: 0.3306 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5756 - val_loss: 0.8922 - val_y1_output_loss: 0.2548 - val_y2_output_loss: 0.6542 - val_y1_output_root_mean_squared_error: 0.5112 - val_y2_output_root_mean_squared_error: 0.7943
# Epoch 470/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4291 - y1_output_loss: 0.1334 - y2_output_loss: 0.2963 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5430 - val_loss: 0.9713 - val_y1_output_loss: 0.2867 - val_y2_output_loss: 0.6896 - val_y1_output_root_mean_squared_error: 0.5422 - val_y2_output_root_mean_squared_error: 0.8230
# Epoch 471/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4305 - y1_output_loss: 0.1214 - y2_output_loss: 0.3099 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.5560 - val_loss: 1.1205 - val_y1_output_loss: 0.2361 - val_y2_output_loss: 0.8679 - val_y1_output_root_mean_squared_error: 0.4942 - val_y2_output_root_mean_squared_error: 0.9361
# Epoch 472/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3681 - y1_output_loss: 0.0974 - y2_output_loss: 0.2698 - y1_output_root_mean_squared_error: 0.3123 - y2_output_root_mean_squared_error: 0.5202 - val_loss: 1.0066 - val_y1_output_loss: 0.2726 - val_y2_output_loss: 0.7663 - val_y1_output_root_mean_squared_error: 0.5279 - val_y2_output_root_mean_squared_error: 0.8532
# Epoch 473/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3303 - y1_output_loss: 0.1041 - y2_output_loss: 0.2239 - y1_output_root_mean_squared_error: 0.3237 - y2_output_root_mean_squared_error: 0.4749 - val_loss: 0.9108 - val_y1_output_loss: 0.2687 - val_y2_output_loss: 0.6707 - val_y1_output_root_mean_squared_error: 0.5241 - val_y2_output_root_mean_squared_error: 0.7976
# Epoch 474/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3737 - y1_output_loss: 0.1051 - y2_output_loss: 0.2692 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 0.9281 - val_y1_output_loss: 0.2429 - val_y2_output_loss: 0.7213 - val_y1_output_root_mean_squared_error: 0.5005 - val_y2_output_root_mean_squared_error: 0.8231
# Epoch 475/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4599 - y1_output_loss: 0.1154 - y2_output_loss: 0.3445 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.5868 - val_loss: 0.8931 - val_y1_output_loss: 0.2690 - val_y2_output_loss: 0.6611 - val_y1_output_root_mean_squared_error: 0.5228 - val_y2_output_root_mean_squared_error: 0.7873
# Epoch 476/500
# 614/614 [==============================] - 0s 205us/sample - loss: 0.4315 - y1_output_loss: 0.1138 - y2_output_loss: 0.3166 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5636 - val_loss: 1.4617 - val_y1_output_loss: 0.3930 - val_y2_output_loss: 1.0563 - val_y1_output_root_mean_squared_error: 0.6379 - val_y2_output_root_mean_squared_error: 1.0270
# Epoch 477/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4523 - y1_output_loss: 0.1396 - y2_output_loss: 0.3110 - y1_output_root_mean_squared_error: 0.3743 - y2_output_root_mean_squared_error: 0.5587 - val_loss: 1.0116 - val_y1_output_loss: 0.3132 - val_y2_output_loss: 0.7278 - val_y1_output_root_mean_squared_error: 0.5640 - val_y2_output_root_mean_squared_error: 0.8328
# Epoch 478/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3960 - y1_output_loss: 0.1156 - y2_output_loss: 0.2774 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 1.1345 - val_y1_output_loss: 0.2566 - val_y2_output_loss: 0.8661 - val_y1_output_root_mean_squared_error: 0.5143 - val_y2_output_root_mean_squared_error: 0.9327
# Epoch 479/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3936 - y1_output_loss: 0.1090 - y2_output_loss: 0.2818 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.5325 - val_loss: 1.0592 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.8461 - val_y1_output_root_mean_squared_error: 0.5104 - val_y2_output_root_mean_squared_error: 0.8937
# Epoch 480/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3898 - y1_output_loss: 0.1060 - y2_output_loss: 0.2837 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5325 - val_loss: 1.4149 - val_y1_output_loss: 0.3418 - val_y2_output_loss: 1.0456 - val_y1_output_root_mean_squared_error: 0.5948 - val_y2_output_root_mean_squared_error: 1.0301
# Epoch 481/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5980 - y1_output_loss: 0.1236 - y2_output_loss: 0.4784 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.6882 - val_loss: 1.2312 - val_y1_output_loss: 0.2786 - val_y2_output_loss: 1.0266 - val_y1_output_root_mean_squared_error: 0.5322 - val_y2_output_root_mean_squared_error: 0.9736
# Epoch 482/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3428 - y1_output_loss: 0.0959 - y2_output_loss: 0.2457 - y1_output_root_mean_squared_error: 0.3109 - y2_output_root_mean_squared_error: 0.4962 - val_loss: 1.0846 - val_y1_output_loss: 0.2594 - val_y2_output_loss: 0.8765 - val_y1_output_root_mean_squared_error: 0.5141 - val_y2_output_root_mean_squared_error: 0.9057
# Epoch 483/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4083 - y1_output_loss: 0.1095 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.5458 - val_loss: 1.0017 - val_y1_output_loss: 0.2734 - val_y2_output_loss: 0.7289 - val_y1_output_root_mean_squared_error: 0.5314 - val_y2_output_root_mean_squared_error: 0.8481
# Epoch 484/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3541 - y1_output_loss: 0.0985 - y2_output_loss: 0.2595 - y1_output_root_mean_squared_error: 0.3150 - y2_output_root_mean_squared_error: 0.5048 - val_loss: 1.3177 - val_y1_output_loss: 0.3543 - val_y2_output_loss: 1.0015 - val_y1_output_root_mean_squared_error: 0.6049 - val_y2_output_root_mean_squared_error: 0.9756
# Epoch 485/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3434 - y1_output_loss: 0.0997 - y2_output_loss: 0.2437 - y1_output_root_mean_squared_error: 0.3165 - y2_output_root_mean_squared_error: 0.4932 - val_loss: 1.2342 - val_y1_output_loss: 0.2443 - val_y2_output_loss: 1.0333 - val_y1_output_root_mean_squared_error: 0.5021 - val_y2_output_root_mean_squared_error: 0.9910
# Epoch 486/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3530 - y1_output_loss: 0.0974 - y2_output_loss: 0.2544 - y1_output_root_mean_squared_error: 0.3105 - y2_output_root_mean_squared_error: 0.5066 - val_loss: 0.8749 - val_y1_output_loss: 0.2694 - val_y2_output_loss: 0.6276 - val_y1_output_root_mean_squared_error: 0.5284 - val_y2_output_root_mean_squared_error: 0.7718
# Epoch 487/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4496 - y1_output_loss: 0.1323 - y2_output_loss: 0.3146 - y1_output_root_mean_squared_error: 0.3646 - y2_output_root_mean_squared_error: 0.5627 - val_loss: 0.8901 - val_y1_output_loss: 0.2315 - val_y2_output_loss: 0.6839 - val_y1_output_root_mean_squared_error: 0.4884 - val_y2_output_root_mean_squared_error: 0.8072
# Epoch 488/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3252 - y1_output_loss: 0.0959 - y2_output_loss: 0.2319 - y1_output_root_mean_squared_error: 0.3048 - y2_output_root_mean_squared_error: 0.4820 - val_loss: 0.9197 - val_y1_output_loss: 0.2827 - val_y2_output_loss: 0.6467 - val_y1_output_root_mean_squared_error: 0.5389 - val_y2_output_root_mean_squared_error: 0.7933
# Epoch 489/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3410 - y1_output_loss: 0.0986 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3151 - y2_output_root_mean_squared_error: 0.4916 - val_loss: 0.9116 - val_y1_output_loss: 0.2588 - val_y2_output_loss: 0.6870 - val_y1_output_root_mean_squared_error: 0.5154 - val_y2_output_root_mean_squared_error: 0.8037
# Epoch 490/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3771 - y1_output_loss: 0.1072 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.5187 - val_loss: 0.9195 - val_y1_output_loss: 0.2737 - val_y2_output_loss: 0.6653 - val_y1_output_root_mean_squared_error: 0.5285 - val_y2_output_root_mean_squared_error: 0.8001
# Epoch 491/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4419 - y1_output_loss: 0.1074 - y2_output_loss: 0.3323 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.5781 - val_loss: 0.8732 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.6361 - val_y1_output_root_mean_squared_error: 0.5049 - val_y2_output_root_mean_squared_error: 0.7863
# Epoch 492/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5351 - y1_output_loss: 0.1285 - y2_output_loss: 0.4045 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.6370 - val_loss: 1.0826 - val_y1_output_loss: 0.2879 - val_y2_output_loss: 0.7949 - val_y1_output_root_mean_squared_error: 0.5451 - val_y2_output_root_mean_squared_error: 0.8863
# Epoch 493/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4357 - y1_output_loss: 0.1091 - y2_output_loss: 0.3261 - y1_output_root_mean_squared_error: 0.3281 - y2_output_root_mean_squared_error: 0.5728 - val_loss: 1.3019 - val_y1_output_loss: 0.3655 - val_y2_output_loss: 0.9726 - val_y1_output_root_mean_squared_error: 0.6135 - val_y2_output_root_mean_squared_error: 0.9620
# Epoch 494/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3377 - y1_output_loss: 0.1076 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 1.0936 - val_y1_output_loss: 0.4190 - val_y2_output_loss: 0.6673 - val_y1_output_root_mean_squared_error: 0.6591 - val_y2_output_root_mean_squared_error: 0.8119
# Epoch 495/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4295 - y1_output_loss: 0.1177 - y2_output_loss: 0.3105 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.5592 - val_loss: 1.0351 - val_y1_output_loss: 0.2653 - val_y2_output_loss: 0.8024 - val_y1_output_root_mean_squared_error: 0.5216 - val_y2_output_root_mean_squared_error: 0.8735
# Epoch 496/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4930 - y1_output_loss: 0.1311 - y2_output_loss: 0.3675 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.6012 - val_loss: 2.0705 - val_y1_output_loss: 0.2924 - val_y2_output_loss: 1.8398 - val_y1_output_root_mean_squared_error: 0.5491 - val_y2_output_root_mean_squared_error: 1.3300
# Epoch 497/500
# 614/614 [==============================] - 0s 302us/sample - loss: 0.5045 - y1_output_loss: 0.1122 - y2_output_loss: 0.3936 - y1_output_root_mean_squared_error: 0.3330 - y2_output_root_mean_squared_error: 0.6274 - val_loss: 1.3470 - val_y1_output_loss: 0.4706 - val_y2_output_loss: 0.9267 - val_y1_output_root_mean_squared_error: 0.6884 - val_y2_output_root_mean_squared_error: 0.9344
# Epoch 498/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3953 - y1_output_loss: 0.1169 - y2_output_loss: 0.2766 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.5274 - val_loss: 0.8230 - val_y1_output_loss: 0.2432 - val_y2_output_loss: 0.6157 - val_y1_output_root_mean_squared_error: 0.4961 - val_y2_output_root_mean_squared_error: 0.7595
# Epoch 499/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3299 - y1_output_loss: 0.1008 - y2_output_loss: 0.2305 - y1_output_root_mean_squared_error: 0.3176 - y2_output_root_mean_squared_error: 0.4785 - val_loss: 1.1211 - val_y1_output_loss: 0.2543 - val_y2_output_loss: 0.8544 - val_y1_output_root_mean_squared_error: 0.5134 - val_y2_output_root_mean_squared_error: 0.9260
# Epoch 500/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3161 - y1_output_loss: 0.1026 - y2_output_loss: 0.2187 - y1_output_root_mean_squared_error: 0.3139 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 1.4514 - val_y1_output_loss: 0.3713 - val_y2_output_loss: 1.0545 - val_y1_output_root_mean_squared_error: 0.6173 - val_y2_output_root_mean_squared_error: 1.0346

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 41us/sample - loss: 1.4514 - y1_output_loss: 0.3769 - y2_output_loss: 1.0657 - y1_output_root_mean_squared_error: 0.6173 - y2_output_root_mean_squared_error: 1.0346
# Loss = 1.4513926490560753, Y1_loss = 0.3769378364086151, Y1_mse = 0.6172937154769897, Y2_loss = 1.0657069683074951, Y2_mse = 1.034572958946228

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
